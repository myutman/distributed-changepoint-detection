# %%
from importlib import reload

import myutman

reload(myutman.stand)
reload(myutman.stand.stand_utils)
reload(myutman.streaming_algo)
reload(myutman.generation)
reload(myutman.fuse)

import myutman.stand
import myutman.streaming_algo
import myutman.generation
import myutman.fuse

from myutman.stand.stand_utils import  show_boxplots, show_plot_by_p_levels, show_boxplots_by_p_levels, \
    show_plot_by_nnodes

import json

# %%
show_boxplots('FDR', [results[0][0], results[0][1]], ['centralized', 'roundrobin'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-11145ad3ad54> in <module>
# ----> 1 show_boxplots('FDR', [results[0][0], results[0][1]], ['centralized', 'roundrobin'])
#
# ~/Documents/distributed-changepoint-detection/myutman/stand_utils.py in show_boxplots(val_name, results, legends)
#     165
#     166 def show_boxplots(val_name: str, results: List[List[Dict[str, float]]], legends: List[str]):
# --> 167     valss = [[res[val_name] for res in result if res[val_name] is not None] for result in results]
#     168     plt.boxplot(valss, labels=legends)
#     169     plt.ylabel(val_name)
#
# ~/Documents/distributed-changepoint-detection/myutman/stand_utils.py in <listcomp>(.0)
#     165
#     166 def show_boxplots(val_name: str, results: List[List[Dict[str, float]]], legends: List[str]):
# ...

# %%
show_boxplots('client_MDR', results[0], ['centralized', 'roundrobin', 'client_dependent', 'terminal_dependent'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d7c11c7a2d26> in <module>
# ----> 1 show_boxplots('client_MDR', results[0], ['centralized', 'roundrobin', 'client_dependent', 'terminal_dependent'])
#
# ~/Documents/distributed-changepoint-detection/myutman/stand_utils.py in show_boxplots(val_name, results, legends)
#     165
#     166 def show_boxplots(val_name: str, results: List[List[Dict[str, float]]], legends: List[str]):
# --> 167     valss = [[res[val_name] for res in result if res[val_name] is not None] for result in results]
#     168     plt.boxplot(valss, labels=legends)
#     169     plt.ylabel(val_name)
#
# ~/Documents/distributed-changepoint-detection/myutman/stand_utils.py in <listcomp>(.0)
#     165
#     166 def show_boxplots(val_name: str, results: List[List[Dict[str, float]]], legends: List[str]):
# ...

# %%
show_boxplots('client_FDR', results[0], ['centralized', 'roundrobin', 'client_dependent', 'terminal_dependent'])

# %%
show_boxplots('terminal_MDR', results[0], ['centralized', 'roundrobin', 'client_dependent', 'terminal_dependent'])

# %%
show_boxplots('terminal_FDR', results[0], ['centralized', 'roundrobin', 'client_dependent', 'terminal_dependent'])

# %%
show_boxplots('client_latency', results[0], ['centralized', 'roundrobin', 'client_dependent', 'terminal_dependent'])

# %%
show_boxplots('terminal_latency', results[0], ['centralized', 'roundrobin', 'client_dependent', 'terminal_dependent'])

# %%
show_boxplots('client_MDR', results[0], ['centralized', 'roundrobin', 'client_dependent'])

# %%
show_boxplots('client_FDR', results[0], ['centralized', 'roundrobin', 'client_dependent'])

# %%
show_boxplots('client_latency', results[0], ['centralized', 'roundrobin', 'client_dependent'])

# %%
with open('centralized_vs_roundrobin_v2_p=[0.01, 0.05, 0.1]_nnodes=[4, 8, 16]_original_experiments.json') as input_file:
    results = json.load(input_file)

# %% [markdown]
# # Maximum fuse
# ## Original experiment #1

# %%
with open('../results/centralized_vs_roundrobin_p=[0.01, 0.05, 0.1]_nnodes=[4, 8, 16]_original_experiment1_algo_fixed_iter_no_change_period_noise.json') as input_file:
    results = json.load(input_file)

# %%
show_plot_by_p_levels('late_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('true_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('MDR', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('latency', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_boxplots('latency', results[0][3], ['p=0.01', 'p=0.05', 'p=0.1'])

# %%
show_boxplots_by_p_levels('FDR', results[0], ['centralized', 'roundrobin 4', 'roundrobin 8', 'roundrobin 16'])
# Out:
# (3, 4, 5)
# (4, 5)
# (4, 5)
# (4, 5)

# %% [markdown]
# ## Canonical experiment

# %%
with open('../results/centralized_vs_roundrobin_p=[0.01, 0.05, 0.1]_nnodes=[4, 8, 16]_canonical_experiment.json') as input_file:
    results = maximum_results = json.load(input_file)

# %%
show_plot_by_p_levels('late_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('true_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('MDR', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('latency', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_boxplots('latency', results[0][3], ['p=0.01', 'p=0.05', 'p=0.1'])

# %%
show_boxplots_by_p_levels('FDR', results[0], ['centralized', 'roundrobin 4', 'roundrobin 8', 'roundrobin 16'])
# Out:
# (3, 4, 5)
# (4, 5)
# (4, 5)
# (4, 5)

# %% [markdown]
# # Mean fuse
# ## Original experiment #1

# %%
with open('../results/centralized_vs_roundrobin_p=[0.01, 0.05, 0.1]_nnodes=[4, 8, 16]_original_experiment1_mean_duse_algo_fixed_iter_no_change_period_noise.json') as input_file:
    results = json.load(input_file)

# %%
show_plot_by_p_levels('late_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('true_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('MDR', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('latency', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_boxplots('latency', results[0][3], ['p=0.01', 'p=0.05', 'p=0.1'])

# %%
show_boxplots_by_p_levels('FDR', results[0], ['centralized', 'roundrobin 4', 'roundrobin 8', 'roundrobin 16'])
# Out:
# (3, 4, 5)
# (4, 5)
# (4, 5)
# (4, 5)

# %% [markdown]
# ## Canonical experiment

# %%
with open('../results/centralized_vs_roundrobin_p=[0.01, 0.05, 0.1]_nnodes=[4, 8, 16]_canonical_experiment_mean_fuse_rule.json') as input_file:
    results = mean_results = json.load(input_file)

# %%
show_plot_by_p_levels('late_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('true_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('MDR', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('latency', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_nnodes('latency', results[0])

# %%
show_boxplots('latency', results[0][3], ['p=0.01', 'p=0.05', 'p=0.1'])

# %%
show_boxplots_by_p_levels('FDR', results[0], ['centralized', 'roundrobin 4', 'roundrobin 8', 'roundrobin 16'])
# Out:
# (3, 4, 5)
# (4, 5)
# (4, 5)
# (4, 5)

# %% [markdown]
# # Median fuse
# ## Original experiment #1

# %%
with open('../results/centralized_vs_roundrobin_p=[0.01, 0.05, 0.1]_nnodes=[4, 8, 16]_original_experiment1_median_duse_algo_fixed_iter_no_change_period_noise.json') as input_file:
    results = json.load(input_file)

# %%
show_plot_by_p_levels('late_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('true_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('MDR', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('latency', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_boxplots('latency', results[0][3], ['p=0.01', 'p=0.05', 'p=0.1'])

# %%
show_boxplots_by_p_levels('FDR', results[0], ['centralized', 'roundrobin 4', 'roundrobin 8', 'roundrobin 16'])
# Out:
# (3, 4, 5)
# (4, 5)
# (4, 5)
# (4, 5)

# %% [markdown]
# ## Canonical experiment

# %%
with open('../results/centralized_vs_roundrobin_p=[0.01, 0.05, 0.1]_nnodes=[4, 8, 16]_canonical_experiment_median_fuse_rule.json') as input_file:
    results = median_results = json.load(input_file)

# %%
show_plot_by_p_levels('late_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('true_detections', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('MDR', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_plot_by_p_levels('latency', results[0], ['centralized', 'roundrobin 4 nodes', 'roundrobin 8 nodes', 'roundrobin 16 nodes'])

# %%
show_boxplots('latency', results[0][3], ['p=0.01', 'p=0.05', 'p=0.1'])

# %% [markdown]
# # Fuses comparison

# %%
results = [[[x[i] for x in maximum_results[0]], [x[i] for x in mean_results[0]], [x[i] for x in median_results[0]]] for i in range(3)]

# %%
results = [[[list(np.concatenate(x)) for x in maximum_results[0]], [list(np.concatenate(x)) for x in mean_results[0]], [list(np.concatenate(x)) for x in median_results[0]]] for i in range(3)]

# %%
results
# Out:
# [[[[{'changes': 20,
#      'detections': 20,
#      'true_detections': 19,
#      'false_detections': 1,
#      'late_detections': 0,
#      'total_errored_detections': 1,
#      'missed_changes': 1,
#      'TDR': 0.95,
#      'MDR': 0.050000000000000044,
#      'FDR': 0.05,
#      'latency': 44.421052631578945},
#     {'changes': 20,
#      'detections': 19,
#      'true_detections': 19,
#      'false_detections': 0,
#      'late_detections': 0,
#      'total_errored_detections': 0,
#      'missed_changes': 1,
#      'TDR': 0.95,
#      'MDR': 0.050000000000000044,
#      'FDR': 0.0,
#      'latency': 45.21052631578947},
#     {'changes': 20,
#      'detections': 19,
#      'true_detections': 19,
#      'false_detections': 0,
#      'late_detections': 0,
#      'total_errored_detections': 0,
#      'missed_changes': 1,
#      'TDR': 0.95,
#      'MDR': 0.050000000000000044,
#      'FDR': 0.0,
#      'latency': 46.21052631578947},
#     {'changes': 20,
#      'detections': 19,
# ...

# %%
show_plot_by_nnodes('latency', results[0], ['maximum', 'mean', 'median'])

# %%
show_plot_by_nnodes('latency', results[1], ['maximum', 'mean', 'median'])

# %%
show_plot_by_nnodes('latency', results[2], ['maximum', 'mean', 'median'])

# %%
np.concatenate([[{0: 1}], [{0: 2}]])
# Out:
# array([{0: 1}, {0: 2}], dtype=object)
